# %% [markdown]
# # MY JUPYTER NOTEBOOK

# %% [markdown]
# ## **PREETHI P RAMANUJAM**
# ### Aspiring Sports Analyst

# %% [markdown]
# *I love Data Science because it gives us the freedom to analyse, manipulate and use \n different algorithms on data that will give us the desired and exciting solution*

# %% [markdown]
# ### In the next cell, values have been assigned to a and b and then the sum of both values are assigned to c.

# %%
a= 2
b= 4
c = a+b
c
# Out:
# 6

# %% [markdown]
# [To feel self motivated please visit this page](https://www.tonyrobbins.com/)
#
# Below are the marks scored by four students:
#
#  | S.no | Name | Marks |
#  |:----:|:----:|:-----:|
#  |1     | Rob  |85     |
#  |2     | Rick |98     |
#  |3     |Roy   | 92    |
#  |4     |Spock |83     |
#
#  From the above table we can conclude that
#  * Rick scored the first mark
#  * Second comes Roy
#  * Third comes Rob
#  * Finally we have Spock
#
#  Important things in life are :
#  1. Peace
#  2. Health
#  3. Family and Relationships
#  4. Purpose
#
#  **~Things take time~**
#
#  ![Cin-removebg-preview.png](attachment:Cin-removebg-preview.png)
